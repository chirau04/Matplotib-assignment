# %% [markdown]
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK.

# %% [markdown]
# Matplotlib is widely used for creating static, animated, and interactive visualizations in Python. It allows users to create various types of plots to visualize data effectively.Here are five plots that can be created using the matplotlib.pyplot module:

# %% [markdown]
# 1. Line plot: Used to visualize data points connected by straight line segments.
# 2. Scatter plot: Used to visualize the relationship between two variables by plotting points on a 2D plane.
# 3. Histogram: Used to represent the distribution of numerical data by dividing the data into bins and displaying the frequency of observations in each bin.
# 4. Bar plot: Used to compare the values of different categories by representing them as bars of varying heights.
# 5. Pie chart: Used to represent the proportions of categorical data as slices of a circular pie.

# %% [markdown]
# A scatter plot is a type of plot that displays the relationship between two variables by representing individual data points on a two-dimensional plane. Each data point is represented by a marker, such as a dot or a circle, whose position corresponds to the values of the two variables.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set random seed for reproducibility
np.random.seed(3)

# Generate data for x and y
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Plot scatter plot
plt.scatter(x, y)

# Add title and labels
plt.title("Scatter Plot")
plt.xlabel("X")
plt.ylabel("Y")

# Show plot
plt.show()

# %% [markdown]
# The subplot function in Matplotlib is used to create a grid of subplots within a single figure. It allows you to plot multiple plots (subplots) in a single figure, arranged in rows and columns. This is particularly useful when you want to compare different datasets or visualize multiple aspects of your data side by side.The subplot function takes three arguments: the number of rows, the number of columns, and the index of the subplot to create. With these arguments, you can specify the layout of the subplot grid and select the position of each subplot within the grid.For example, subplot(2, 2, 1) creates a grid with 2 rows and 2 columns and selects the first subplot (top-left corner), subplot(2, 2, 2) selects the second subplot (top-right corner), and so on.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate some sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure with a grid of subplots
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)  # First subplot in a 1x2 grid
plt.plot(x, y1)
plt.title('Sin(x)')

plt.subplot(1, 2, 2)  # Second subplot in a 1x2 grid
plt.plot(x, y2)
plt.title('Cos(x)')

plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Line 1
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

# Data for Line 2
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

# Plotting Line 1
plt.plot(x1, y1, label='Line 1')

# Plotting Line 2
plt.plot(x2, y2, label='Line 2')

# Adding title and labels
plt.title('Line Plot')
plt.xlabel('X')
plt.ylabel('Y')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Line 3
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

# Data for Line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Plotting Line 3
plt.plot(x3, y3, label='Line 3')

# Plotting Line 4
plt.plot(x4, y4, label='Line 4')

# Adding title and labels
plt.title('Line Plot')
plt.xlabel('X')
plt.ylabel('Y')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# A bar plot is a type of plot that presents categorical data with rectangular bars with lengths proportional to the values they represent. The bars can be plotted vertically or horizontally, depending on the orientation of the plot. Bar plots are commonly used to compare the values of different categories or to visualize the distribution of categorical data.A vertical bar plot is useful when comparing the values of different categories, while a horizontal bar plot is useful when the category names are long or when you want to emphasize the relative sizes of the values.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
company = np.array(['Apple', 'Microsoft', 'Google', 'AMD'])
profit = np.array([3000, 8000, 1000, 10000])

# Vertical bar plot
plt.figure(figsize=(8, 6))
plt.bar(company, profit, color='blue')
plt.title('Profit by Company (Vertical Bar Plot)')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()

# Horizontal bar plot
plt.figure(figsize=(8, 6))
plt.barh(company, profit, color='green')
plt.title('Profit by Company (Horizontal Bar Plot)')
plt.xlabel('Profit')
plt.ylabel('Company')
plt.show()
